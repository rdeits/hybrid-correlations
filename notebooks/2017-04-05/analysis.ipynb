# %%
using Colors
using AxisArrays

# %%
cmap = colormap("RdBu", 101)
function colorize(value)
    isnan(value) ? colorant"white" : cmap[round(Int, value * 50 + 51)]
end
# Out:
# colorize (generic function with 1 method)

# %%
include("main.jl")
# Out:
# c

# %%
samples = c.collect_data(1000);
# Out:
# WARNING: Gurobi reported infeasible or unbounded. Set InfUnbdInfo=1 for more specific status.

# %%
correlations = c.correlate(samples);

# %%
colorize.(linspace(-1, 1))
# Out:
# 50-element Array{ColorTypes.RGB{Float64},1}:
#  RGB{Float64}(0.37863,0.00561671,0.00638272)
#  RGB{Float64}(0.465097,0.0260303,0.0233857)
#  RGB{Float64}(0.546246,0.0640568,0.0542521)
#  RGB{Float64}(0.621563,0.105971,0.0888854)
#  RGB{Float64}(0.690636,0.149945,0.124848)
#  RGB{Float64}(0.753139,0.195668,0.162188)
#  RGB{Float64}(0.808801,0.242834,0.20102)
#  RGB{Float64}(0.857373,0.291171,0.24151)
#  RGB{Float64}(0.898624,0.340413,0.283842)
#  RGB{Float64}(0.933014,0.389742,0.327562)
#  RGB{Float64}(0.961558,0.438177,0.371843)
#  RGB{Float64}(0.985055,0.485206,0.416189)
#  RGB{Float64}(1.0,0.530579,0.460283)
#  ⋮
#  RGB{Float64}(0.399376,0.655567,0.881771)
#  RGB{Float64}(0.358063,0.619392,0.860311)
#  RGB{Float64}(0.318005,0.581247,0.834874)
#  RGB{Float64}(0.279706,0.541204,0.804653)
#  RGB{Float64}(0.24379,0.499397,0.768642)
#  RGB{Float64}(0.210522,0.456008,0.726117)
#  RGB{Float64}(0.179281,0.411198,0.677204)
#  RGB{Float64}(0.14942,0.365126,0.622113)
#  RGB{Float64}(0.120408,0.317955,0.561067)
#  RGB{Float64}(0.0918714,0.269865,0.494334)
#  RGB{Float64}(0.063636,0.221069,0.422277)
#  RGB{Float64}(0.0358504,0.171831,0.345409)

# %%
colorize.(correlations[
    Axis{:constraint}(:force_without_contact_right),
    Axis{:contact_side}(:right)
        ])
# Out:
# 9×10 Array{ColorTypes.RGB,2}:
#  RGB{Float64}(1.0,0.574176,0.503903)       …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.974598,0.972607,0.975359)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.914906,0.890231)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.940553,0.922751)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.974598,0.972607,0.975359)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.916261,0.966001,0.992996)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.864547,0.942559,0.987164)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.8467,0.934179,0.985081)       RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.810116,0.916512,0.98064)      RGB{N0f8}(1.0,1.0,1.0)

# %%
colorize.(correlations[
    Axis{:constraint}(:force_without_contact_left),
    Axis{:contact_side}(:left)])
# Out:
# 9×10 Array{ColorTypes.RGB,2}:
#  RGB{Float64}(1.0,0.574176,0.503903)       …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.932883,0.973281,0.99483)      RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.927895,0.906638)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.940553,0.922751)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.974598,0.972607,0.975359)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.932883,0.973281,0.99483)   …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.89933,0.95846,0.991113)       RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.828555,0.9255,0.98291)        RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.753099,0.887591,0.9731)       RGB{N0f8}(1.0,1.0,1.0)

# %%
colorize.(correlations[
    Axis{:constraint}(:normal_force_right),
    Axis{:contact_side}(:left)
    ])
# Out:
# 9×10 Array{ColorTypes.RGB,2}:
#  RGB{Float64}(1.0,0.814078,0.767192)       …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.829597,0.785637)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.829597,0.785637)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.873877,0.839247)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.952887,0.93857)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.932883,0.973281,0.99483)   …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.882091,0.950649,0.989172)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.810116,0.916512,0.98064)      RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.693716,0.855507,0.964112)     RGB{N0f8}(1.0,1.0,1.0)

# %%
colorize.(correlations[
    Axis{:constraint}(:normal_force_left),
    Axis{:contact_side}(:left)
        ])
# Out:
# 9×10 Array{ColorTypes.RGB,2}:
#  RGB{Float64}(0.753099,0.887591,0.9731)    …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.772381,0.897568,0.975751)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.772381,0.897568,0.975751)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.828555,0.9255,0.98291)        RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.932883,0.973281,0.99483)      RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.952887,0.93857)        …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.914906,0.890231)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.859489,0.821667)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.76514,0.710179)           RGB{N0f8}(1.0,1.0,1.0)

# %%
colorize.(correlations[
    Axis{:constraint}(:limb_ub),
    Axis{:contact_side}(:right)
        ])
# Out:
# 9×10 Array{ColorTypes.RGB,2}:
#  RGB{N0f8}(1.0,1.0,1.0)                    …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.932883,0.973281,0.99483)      RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)                       RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.864547,0.942559,0.987164)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.864547,0.942559,0.987164)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.864547,0.942559,0.987164)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.882091,0.950649,0.989172)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.89933,0.95846,0.991113)       RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.952887,0.93857)           RGB{N0f8}(1.0,1.0,1.0)

# %%
colorize.(correlations[
    Axis{:constraint}(:limb_ub),
    Axis{:contact_side}(:left)
        ])
# Out:
# 9×10 Array{ColorTypes.RGB,2}:
#  RGB{N0f8}(1.0,1.0,1.0)                    …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.932883,0.973281,0.99483)      RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)                       RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.864547,0.942559,0.987164)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.940553,0.922751)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.927895,0.906638)       …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.927895,0.906638)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.927895,0.906638)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.974598,0.972607,0.975359)     RGB{N0f8}(1.0,1.0,1.0)

# %%
colorize.(correlations[
    Axis{:constraint}(:contact_at_distance_right),
    Axis{:contact_side}(:right)
        ])
# Out:
# 9×10 Array{ColorTypes.RGB,2}:
#  RGB{Float64}(0.916261,0.966001,0.992996)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.694062,0.630435)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.887904,0.856536)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.940553,0.922751)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.952887,0.93857)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.974598,0.972607,0.975359)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.974598,0.972607,0.975359)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.952887,0.93857)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.974598,0.972607,0.975359)     RGB{N0f8}(1.0,1.0,1.0)

# %%
colorize.(correlations[
    Axis{:constraint}(:contact_at_distance_right),
    Axis{:contact_side}(:left)
        ])
# Out:
# 9×10 Array{ColorTypes.RGB,2}:
#  RGB{Float64}(0.713755,0.866571,0.9673)    …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.772381,0.897568,0.975751)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.791389,0.907205,0.978259)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.882091,0.950649,0.989172)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.916261,0.966001,0.992996)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.952887,0.93857)        …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.940553,0.922751)          RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(0.916261,0.966001,0.992996)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,0.940553,0.922751)          RGB{N0f8}(1.0,1.0,1.0)
